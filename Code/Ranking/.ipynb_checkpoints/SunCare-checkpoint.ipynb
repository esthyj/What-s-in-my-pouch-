# %% [markdown]
# ## User Information

# %%
file = open(r'./user_info.txt')
user_info=file.readlines()

name=user_info[0]
name=name.strip()
print("--- "+str(name)+"님의 정보 ---")

age=user_info[1]
age = age.strip()
print('age: ',age)

skinType=user_info[2]
skinType=skinType.strip()
print('skinType: ',skinType)

skinConcern=user_info[3]
print('skinConcern: ',skinConcern)
# Out:
# --- 최윤선님의 정보 ---
# age:  30대
# skinType:  복합성
# skinConcern:  진정

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import re

# %% [markdown]
# ## Dataset Upload

# %%
SunCare=pd.read_csv('./sunCare.csv',encoding='cp949')
pd.set_option('display.max_rows',None)

# %%
Ranked = SunCare[SunCare['나이'].str.contains(age)]
Ranked = Ranked[Ranked['피부타입'].str.contains(skinType)]

#If considered 2 above, but if length is 0: consider only skinType
if len(Ranked)==0:
    Ranked = SunCare[SunCare['피부타입'].str.contains(skinType)]
    
# others
others=pd.merge(Ranked, SunCare, how='outer',indicator=True)
others=others.query('_merge=="right_only"').drop(columns=['_merge'])

#reset index
Ranked.reset_index(inplace=True)
Ranked = Ranked.drop(['index', '랭킹','리뷰수'], axis=1)
Ranked.index=Ranked.index + 1
others.reset_index(inplace=True)
others = others.drop(['index', '랭킹','리뷰수'], axis=1)
others.index=others.index + 1

# %% [markdown]
# ## Recommendation Ranking
# 나이대, 피부타입, 피부고민에 의해 선정된 랭킹 (만약 데이터가 적다면 오직 피부타입으로만 결정됨)

# %%
Ranked
# Out:
#                                                   상품명     가격  \
# 1                    닥터지 그린 마일드 업 선 플러스 기획(50ml+20ml)  29000
# 2      [베스트밀착차단] 셀퓨전씨 레이저 썬스크린 100 50ml 기획(쿨링패드 2매입2)  42000
# 3                      헤라 UV프로텍터 톤업 50ml (SPF50+PA4+)  45000
# 4                                    조선미녀 맑은쌀선크림 50ml  18000
# 5                메이크프렘 유브이 디펜스 미 노 세범 선크림 40ml 1+1 기획  28000
# 6       [프롬젤라PICK] 톤핏선 비건 파데프리 핑베 테라조쿠션 SPF50+ PA++++  24000
# 7            라운드랩 자작나무 수분 톤업 선크림 50ml 기획(클렌저 20ml 증정)  25000
# 8   에스트라 더마UV365 레드진정 톤업 선크림 40ml 기획 (+무기자차선크림 20m...  31000
# 9       [베스트밀착톤업] 셀퓨전씨 토닝 썬스크린 100 50ml 기획(쿨링패드 2매입2)  39000
# 10                         [NEW] 라운드랩 자작나무 수분 선스틱 19g  24000
# 11               [쿨링젤] 아로마티카 수딩 알로에 베라 젤 (300ml500ml)  11000
# 12            라운드랩 자작나무 무기자차 선크림 50ml 기획(클렌저 20ml 증정)  25000
# 13          [단독기획] 아누아 어성초 실키 모이스처 선크림 기획 (50ml+10ml)  25000
# 14                       드림웍스 아임더 리얼 알로에 99%수딩젤 300ml   5800
# 15                [단독기획] 토리든 다이브인 워터리 모이스처 선크림 1+1 기획  25000
# 16                    한율 어린쑥 수분진정 선크림 50ml+20ml 증정 기획  27000
# 17                    아벤느 선 미네랄 크림 50ml SPF50+ PA++++  32000
# 18                                    조선미녀 산들쑥선스틱 18g  18000
# 19         아넷사 퍼펙트 UV 스킨케어 밀크 N 60ml 기획 (+썬패치 2회분 증정)  36000
# 20                    시드물 민중기 무기자차 썬크림 SPF40 PA++ 50g  16400
# 21                      [대용량] AHC 내추럴 퍼펙션 프레쉬 선스틱 22g  19000
# 22            [단독기획] 비플레인 선뮤즈 모이스처 선크림 기획 (50ml+20ml)  26000
# 23       [톤업선크림 쿠션 VER] 달바 워터풀 톤업 선 쿠션 듀오 기획(15g+15g)  52500
# 24  [단독기획] 토리든 다이브인 무기자차 마일드 선크림 60ml 기획 (+20ml 추가...  25000
# 25            로레알파리 UV 디펜더 선크림 50ml 4종 (데일리톤업오일프리아쿠아)  26000
# 26                   닥터올가 프리미엄 선프로텍션 크림 60ml (톤업 선크림)  38000
# 27                                    조선미녀 인삼선세럼 50ml  21000
# 28                            케어존 데일리&패밀리 선크림 시즌 특별기획  20000
# 29           [올리브영 단독기획] 휘게 릴리프 선 모이스처라이저 50ml 1+1 기획  27000
# 30        [퍼프 증정] 라타플랑 미나리 진정 선크림 기획세트 (50ml+20ml 증정)  25000
# 31  라로슈포제 유비데아 안뗄리오스 톤업 라이트 30ml 기획 (+똘러리앙 폼 15ml+...  35000
# 32              마녀공장 파데프리 선크림 모이스처 50ml SPF50+ PA++++  28000
# 33                       아넷사 퍼펙트 UV 선스크린 스킨케어 젤 N 90g  28000
# 34                  에끌라두 UV 오일프리 선크림 SPF50+PA ++++ 기획  28000
# 35                           컬러랩스 화이트태닝 100X 로션 300ml  32000
# 36                         성분에디터 그린토마토 포어 블러링 선크림 50g  24500
#
#                                                    성분              나이     피부타입
# 1   1. 그린마일드 업 선 플러스 50ml(본품+구성품)\n정제수, 징크옥사이드, 프로...             30대      복합성
# 2   정제수, 사이클로펜타실록산, 에칠헥실메톡시신나메이트, 부틸렌글라이콜, 에칠헥실살리실...         20대,30대      복합성
# 3   정제수, 에칠헥실메톡시신나메이트, 글리세린, 부틸렌글라이콜, 비스-에칠헥실옥시페놀메...         20대,30대  건성, 복합성
# 4   정제수, 쌀추출물, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실...             30대  건성, 복합성
# 5   정제수,징크옥사이드,사이클로헥사실록세인,부틸옥틸살리실레이트,프로판다이올,프로필헵틸카...             30대  지성, 복합성
# 6   정제수, 징크옥사이드, 부틸렌글라이콜다이카프릴레이트/다이카프레이트, 티타늄디옥사이드...             30대      복합성
# 7   [본품 : 자작나무 수분 톤업 선크림]\n정제수, 프로판다이올, 다이부틸아디페이트,...             30대  건성, 복합성
# 8   정제수, 부틸렌글라이콜, 글리세린, 디에칠아미노하이드록시벤조일헥실벤조에이트, 호모살...             30대  건성, 복합성
# 9   정제수, 사이클로펜타실록세인, 징크옥사이드, 호모살레이트, 에칠헥실살리실레이트, 코...             30대      복합성
# 10  정제수, 코코-카프릴레이트/카프레이트, 다이부틸아디페이트, 합성왁스, 부틸옥틸살리실...             30대  건성, 복합성
# 11  알로에베라잎추출물, 프로판다이올, 1,2-헥산다이올, 로즈마리잎수, 소듐카보머, 부...             30대      복합성
# 12  1. 자작나무 무기자차 선크림 50ml (본품)\n정제수, 징크옥사이드, 사이클로헥...             30대      복합성
# 13  정제수, 약모밀추출물(30%), 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존,...             30대  건성, 복합성
# 14  ■ 알로에베라잎추출물, 변성알코올, 정제수, 글리세린, 다이프로필렌글라이콜, 부틸렌...             30대      복합성
# 15  정제수, 프로판다이올, 다이부틸아디페이트, 비스-에칠헥실옥시페놀메톡시페닐트리아진, ...             30대  건성, 복합성
# 16  정제수, 다이부틸아디페이트, 부틸옥틸살리실레이트, 폴리메틸실세스퀴옥세인, 디에칠아미...             30대  건성, 복합성
# 17  티타늄디옥사이드\n아쿠아(아벤느 온천수)\n아이소데실네오펜타노에이트\n트라이에틸헥사...             30대  건성, 복합성
# 18  메틸메타크릴레이트크로스폴리머, 합성왁스, 다이부틸아디페이트, 코코-카프릴레이트/카프...         20대,30대      복합성
# 19  다이메티콘, 정제수, 징크옥사이드, 에탄올, 탤크, 옥토크릴렌, 아이소도데케인, 다...             30대      복합성
# 20  대나무수액추출물,사이클로펜타실록산,티타늄디옥사이드(8.58%),마치현추출물,카프릴릭...             30대  지성, 복합성
# 21  다이메티+B3:C67콘,비닐다이메티콘/메티콘실세스퀴옥세인크로스폴리머,폴리에틸렌,세틸...             30대  건성, 복합성
# 22  정제수, 다이부틸아디페이트, 프로판다이올, 폴리메틸실세스퀴옥세인, 다이아이소프로필세...             30대  건성, 복합성
# 23  정제수, 티타늄디옥사이드 (CI 77891), 부틸옥틸살리실레이트, 다이프로필렌글라...             30대  건성, 복합성
# 24  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로필헵틸카프릴레...             30대  건성, 복합성
# 25  정제수 에칠헥실메톡시신나메이트 드로메트리졸트리실록산 글리세린 프로필렌글라이콜 다이메...  20대,30대,40대 이상  건성, 복합성
# 26  알로에베라잎즙, 다이카프릴릴카보네이트, 징크옥사이드, 사이클로펜타실록세인, 티타늄디...             30대  건성, 복합성
# 27  정제수, 인삼추출물, 다이부틸아디페이트, 디에칠아미노하이드록시벤조일헥실벤조에이트, ...             30대  건성, 복합성
# 28  [정품]사이클로펜타실록산, 정제수, 징크옥사이드, 부틸렌글라이콜, 피이지-10디메치...             30대  건성, 복합성
# 29  정제수, 다이부틸아디페이트, 프로판다이올, 변성알코올, 편백수, 에칠헥실트리아존, ...             30대  건성, 복합성
# 30  정제수, 미나리추출물, 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존, 테레프탈...             30대  건성, 복합성
# 31  유비데아 안뗄리오스 톤업 라이트\n정제수 에칠헥실메톡시신나메이트 스쿠알란 티타늄디옥...             30대      복합성
# 32  정제수, 다이부틸아디페이트, 다이프로필렌글라이콜, 티타늄디옥사이드 (CI 77891...             30대  건성, 복합성
# 33  정제수, 에탄올, 에칠헥실메톡시신나메이트, 다이메티콘, 에칠헥실살리실레이트, 피이지...             30대  건성, 복합성
# 34  정제수, 에칠헥실메토시신나메이트, 다이프로필렌글라이콜, 티타늄디옥사이드, 다이부틸아...             30대  건성, 복합성
# 35  정제수, 글리세린, 부틸렌글라이콜, 카프릴릭/카프릭트라이글리세라이드, 나이아신아마이...         20대,30대  건성, 복합성
# 36  정제수, 다이부틸아디페이트, 에칠헥실트리아존, 디에칠아미노하이드록시벤조일헥실벤조에이...             30대      복합성

# %% [markdown]
# ## Others Ranking
# Recommendation Ranking에 제시된 화장품을 제외한 랭킹

# %%
others
# Out:
#                                                   상품명     가격  \
# 1            [1+1올영1위] 달바 워터풀 톤업 선크림 듀오 기획(50ml+50ml)  51000
# 2                 차앤박(CNP) 톤업프로텍션선SPF42 50ml 1+1 단독기획  28000
# 3                  [유리아PICK] 조선미녀 맑은쌀선크림 더블기획세트 50ml2  30000
# 4               라운드랩 자작나무 수분 선크림 50ml 기획(클렌저 20ml 증정)  25000
# 5   [1+1기획] 구달 맑은 어성초 진정 수분 선크림 50ml 1+1 기획 SPF50+...  18000
# 6               [베스트보송톤업] 닥터지 브라이트닝 업 선 플러스 40ml+40ml  40000
# 7   [1+1 기획] 구달 맑은 어성초 진정 무기자차 선크림 50ml 1+1 기획 SPF...  20000
# 8                  식물나라 산소수생기톤업선쿠션 리필기획 2color (2304)  24800
# 9   [수분진정] 넘버즈인 1번 청초 진정맑은 물막선크림 50ml+50ml 듀오기획 (S...  26000
# 10     [올영1위812만개 판매] 달바 워터풀 에센스 선크림 듀오 기획(50ml+50ml)  51000
# 11  식물나라 산소수가벼운수분선젤로션 SPF50+ PA++++ 더블 기획 (60ml+60ml)  25800
# 12             [베스트민감피부] 닥터지 그린 마일드 업 선 플러스 40ml+40ml  37000
# 13          [베스트보송톤업] 닥터지 브라이트닝 업 선 플러스 기획(50ml+20ml)  32000
# 14       넘버즈인 3번 도자기결 파데스킵 톤업베이지 50ml (SPF50+ PA++++)  26000
# 15             에스트라 더마UV365 장벽수분 무기자차 선크림 40ml 1+1 기획  31000
# 16           [베스트밀착차단] 셀퓨전씨 레이저 썬스크린 더블기획 (35ml+35ml)  29400
# 17                  김정문알로에 큐어 알로에 수딩젤 리뉴얼 150ml 1+1기획   9900
# 18  [더보이즈 큐PICK]듀이트리 어반쉐이드 더마 판테놀5 수분 장벽 선 1+1기획(4...  30000
# 19        [디렉터파이개발]에뛰드 순정 디렉터 수분 선크림 1+1기획(50ml+50ml)  25000
# 20         [증량기획] 에스쁘아 워터 스플래쉬 선크림 세라마이드 60ml+20ml 세트  22000
# 21     [디렉터파이개발]에뛰드 순정 디렉터 무기자차 선크림 1+1기획 (50ml+50ml)  25000
# 22                 토코보 바이오 워터리 선크림 50mL SPF50+ PA++++  24000
# 23             [무기자차논나노] 로벡틴 아쿠아 수딩 선크림 35ml 1+1 기획세트  42000
# 24                메이크프렘 유브이 디펜스 미 카밍톤업선크림 40ml 1+1 기획  28000
# 25           [박세리 공동개발  대용량 출시] AHC 마스터즈 에어리치 선스틱 22g  21000
# 26                 아떼 비건 릴리프 선 에센스 대용량 기획 (70ml+40ml)  42000
# 27    [올영1위812만개 판매] 달바 워터풀 마일드 선크림 듀오 기획 (50ml+50ml)  51000
# 28              [수분] 닥터지 레드 블레미쉬 수딩 업 선 기획(50ml+20ml)  29000
# 29  [듀오기획] 넘버즈인 3번 도자기결 파데스킵 톤업베이지 35ml+35ml (SPF5...  32000
# 30  [한정기획수분] 닥터지 레드 블레미쉬 수딩 업 선 50ml 1+1 한정 기획(볼펜 ...  29000
# 31       [파데프리] 넘버즈인 3번 도자기결 고이빚은 세라믹쿠션 SPF50+ PA++++  28000
# 32               메이크프렘 유브이 디펜스 미 워터리캡슐선크림 40ml 1+1 기획  28000
# 33          [단독기획] 비플레인 선뮤즈 톤업&코렉팅 선크림 기획 (50ml+20ml)  26000
# 34           브링그린 알로에99% 수딩젤 300ml단품더블기획(300ml+300ml)  13600
# 35    [더보이즈 큐PICK]듀이트리 어반쉐이드 안티폴루션 선 1+1기획(50ml+50ml)  30000
# 36  [디렉터파이 PICK] 싸이닉 엔조이 슈퍼 마일드 선 에센스 더블 기획 (50ml+...  15000
# 37                 비레디 블루 수분 선크림 50ml 기획세트 (+20ml 증정)  25000
# 38                비욘드 엔젤아쿠아 수분 수딩젤 더블기획 (200ml+200ml)  15000
# 39  [유기자차 선크림]디어,클레어스 올 데이 에어리 선스크린 SPF50+ PA++++ 50g  19500
# 40                        식물나라 산소수워터프루프선크림(대용량) 100mL  19000
# 41                           [NEW] 비레디 블루 수분 선크림 50ml  25000
# 42                    셀퓨전씨 스틱 썬스크린 19g (SPF50+PA++++)  25000
# 43                          AHC 누드 톤업 크림 내추럴 글로우 40ml  29000
# 44                                 마녀공장 파데프리 선크림 50ml  28000
# 45                  [단독기획] 휘게 비건 선크림 더블 기획(35ml+35ml)  24300
# 46                      피지오겔 레드수딩 AI 센서티브 UV썬스크린 40ml  30000
# 47                  [NEW] 에스쁘아 워터 스플래쉬 선크림 세라마이드 60ml  22000
# 48   [더보이즈 큐PICK]듀이트리 어반쉐이드 커버 앤 핏 선 1+1기획(40ml+40ml)  24000
# 49                           닥터지 레드 블레미쉬 수딩 업 선스틱 21g  27000
# 50         에스쁘아 워터 스플래쉬 선크림 프레쉬 시카 60ml SPF50+ PA++++  22000
# 51                     김정문알로에 큐어 아쿠아 마일드 그린 선 크림 40ml  25000
# 52   [베스트밀착수분] 셀퓨전씨 아쿠아티카 썬스크린 100 50ml 기획(쿨링패드 2매입2)  39000
# 53                          프레시안 워터풀 시카 선로션 35ml (비건)  30000
# 54               [한겹톤업] 아떼 비건 릴리프 톤업 선 비비 50ml 1+1 기획  34000
# 55                              AHC 세이프온 마일드 선 쿠션 25g  29000
# 56                       [화해1위]하멜 비건 아쿠아 글로우 선세럼 50ml  28000
# 57  에스트라 더마UV365 장벽수분 무기자차 선크림 40ml+10ml 기획 (+크림10...  31000
# 58           [베스트밀착톤업] 셀퓨전씨 토닝 썬스크린 1+1기획 (35ml+35ml)  27900
# 59                      차앤박(CNP) 마일드 카밍 선 50ml 1+1 기획  28000
# 60                  아벤느 비-프로텍트 썬크림 SPF50+ PA++++ 30ml  30000
# 61                         [민감피부] 닥터지 그린마일드 업 선스틱 20g  25000
# 62                             블랙몬스터 밸런싱 알로에 선크림 50ml  14000
# 63                             가히 링클 바운스 에센셜 선크림 50ml  24500
# 64               [선우PICK]메디힐 비타마이드 잡티 선크림 50ml 1+1 기획  25000
#
#                                                    성분          나이     피부타입
# 1   정제수, 다이부틸아디페이트, 프로판다이올, 티타늄디옥사이드, 카프릴릭/카프릭트라이글...         20대  건성, 복합성
# 2   정제수, 사이클로펜타실록산, 에칠헥실메톡시신나메이트, 에칠헥실살리실레이트, 징크옥사...         20대      복합성
# 3   정제수, 쌀추출물, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실...         20대  건성, 복합성
# 4   정제수, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실벤조에이트,...         20대  건성, 복합성
# 5   정제수, 다이부틸아디페이트, 프로판다이올, 폴리메틸실세스퀴옥세인, 다이아이소프로필세...         20대  건성, 복합성
# 6   정제수, 사이클로펜타실록세인, 에칠헥실메톡시신나메이트, 징크옥사이드 (CI 7794...         20대      복합성
# 7   정제수, 징크옥사이드, 부틸옥틸살리실레이트, 사이클로헥사실록세인, 카프릴릴메티콘, ...         20대      복합성
# 8   [1호 뽀얀 화이트]\n정제수,부틸옥틸살리실레이트,징크옥사이드,아이소데실네오펜타노에...         20대      복합성
# 9   스페인감초뿌리수(20.55%), 병풀추출물(15%), 약모밀추출물(14.25%), ...         20대  건성, 복합성
# 10  정제수, 에칠헥실메톡시신나메이트, 호모살레이트, 부틸렌글라이콜, 에칠헥실살리실레이트...         20대  건성, 복합성
# 11  정제수, 프로판다이올, 사이클로펜타실록세인, 에칠헥실살리실레이트, 호모살레이트, 다...         20대      복합성
# 12  정제수, 징크옥사이드, 프로판다이올, 부틸옥틸살리실레이트, 프로필헵틸카프릴레이트, ...         20대      복합성
# 13  1. 닥터지 브라이트닝 업 선 플러스 50ml(본품+구성품)\n정제수, 사이클로펜타...         20대      복합성
# 14  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 프로필헵틸카프릴레이트, ...         20대      복합성
# 15  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 부틸옥틸살리실레이트, 프...         20대      복합성
# 16  정제수, 사이클로펜타실록산, 에칠헥실메톡시신나메이트, 부틸렌글라이콜, 에칠헥실살리실...         20대      복합성
# 17  알로에베라잎즙(89.4%),디프로필렌글라이콜,1,2-헥산디올,에탄올,글리세린,트로메...         20대  건성, 복합성
# 18  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 판테놀, 프로판다...         20대  건성, 복합성
# 19  정제수, 다이부틸아디페이트, 프로판다이올, 부틸렌글라이콜, 에칠헥실트리아존, 테레프...         20대  건성, 복합성
# 20  정제수, 부틸렌글라이콜, C12-15알킬벤조에이트, 에칠헥실메톡시신나메이트, 티타늄...         20대  건성, 복합성
# 21  정제수, 아이소노닐아이소노나노에이트, 징크옥사이드, 프로판다이올, C12-15알킬벤...         20대      복합성
# 22  정제수, 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존, 테레프탈릴리덴디캠퍼설포...         20대  건성, 복합성
# 23  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로판다이올, 프...         20대      복합성
# 24  정제수,징크옥사이드,프로필헵틸카프릴레이트,프로판다이올,티타늄디옥사이드,다이실록세인,...      40대 이상      복합성
# 25  메틸메타크릴레이트크로스폴리머, 폴리에틸렌, 카프릴릴메티콘, 코코-카프릴레이트/카프레...         20대  지성, 복합성
# 26  정제수,프로판다이올,사이클로펜타실록세인,에칠헥실살리실레이트,호모살레이트,다이부틸아디...         20대  건성, 복합성
# 27  정제수, C12-15알킬벤조에이트, 티타늄디옥사이드, 벤조트라이아졸릴도데실p-크레솔...         20대  건성, 복합성
# 28  1. 닥터지 레드 블레미쉬 수딩 업 선 50ml (본품)\n\n정제수, 다이부틸아디...         20대  건성, 복합성
# 29  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 프로필헵틸카프릴레이트, ...         20대      복합성
# 30  정제수, 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존, 테레프탈릴리덴디캠퍼설포...         20대  건성, 복합성
# 31  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 프로필헵틸카프릴레이트, ...         20대  건성, 복합성
# 32  정제수,다이부틸아디페이트,폴리메틸실세스퀴옥세인,프로판다이올,디에칠아미노하이드록시벤조...         20대  건성, 복합성
# 33  정제수, 에칠헥실트리아존, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤...         20대      복합성
# 34  ■ 알로에베라잎즙(99%), 글리세린, 알지닌,카보머, 1,2-헥산다이올, 정제수,...         20대      복합성
# 35  정제수, 징크옥사이드, 프로필헵틸카프릴레이트, 프로판다이올, 티타늄디옥사이드, 부틸...         20대      복합성
# 36  정제수, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실벤조에이트,...         20대  건성, 복합성
# 37  정제수, 부틸렌글라이콜, 호모살레이트, 에칠헥실살리실레이트, 변성알코올, 비스-에칠...         20대  건성, 복합성
# 38  정제수, 글리세린, 1,2-헥산다이올, 마데카소사이드, 알로에베라잎추출물, 포도덩굴...         20대  건성, 복합성
# 39  정제수, 다이부틸아디페이트, 부틸옥틸살리실레\n이트, 디에칠아미노하이드록시벤조일헥실...         20대  건성, 복합성
# 40  정제수, 사이클로펜타실록세인, 징크옥사이드, 호모살레이트, 에칠헥실살리실레이트, 폴...         20대      복합성
# 41  정제수, 부틸렌글라이콜, 호모살레이트, 에칠헥실살리실레이트, 변성알코올, 비스-에칠...         20대  건성, 복합성
# 42  정제수, 폴리에틸렌, 다이메티콘, 호모살레이트, 메틸메타크릴레이트크로스폴리머, 에칠...         20대      복합성
# 43  크림: 정제수,카프릴릭/카프릭트라이글리세라이드,프로필렌글라이콜다이벤조에이트,다이프로...      40대 이상       건성
# 44  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로판다이올, 프...         20대      복합성
# 45  정제수, 에탄올, 디에칠아미노하이드록시벤조일헥실벤조에이트, 비스-에칠헥실옥시페놀메톡...         20대  건성, 복합성
# 46  정제수, 에칠헥실메톡시신나메이트, 에칠헥실살리실레이트, C12-15알킬벤조에이트, ...      40대 이상  건성, 복합성
# 47  정제수, 부틸렌글라이콜, C12-15알킬벤조에이트, 에칠헥실메톡시신나메이트, 티타늄...         20대  건성, 복합성
# 48  정제수, 티타늄디옥사이드, 페닐트라이메티콘, 부틸렌글라이콜, 부틸옥틸살리실레이트, ...         20대      복합성
# 49  정제수, 코코-카프릴레이트/카프레이트, 다이부틸아디페이트, 합성왁스, 부틸옥틸살리실...         20대  건성, 복합성
# 50  정제수, 다이부틸아디페이트, 프로판다이올, 변성알코올, 부틸옥틸살리실레이트, 에칠헥...         20대  건성, 복합성
# 51  알로에베라잎즙, 징크옥사이드, 사이클로헥사실록세인, 메틸트라이메티콘, 부틸 옥틸살리...         20대  건성, 복합성
# 52  정제수, 다이부틸아디페이트, 프로판다이올, 변성알코올, 에칠헥실트리아존, 테레프탈릴...         20대  건성, 복합성
# 53  정제수, 변성알코올, 에칠헥실메톡시신나메이트, 에칠헥실살리실레이트, 부틸렌글라이콜,...         20대  건성, 복합성
# 54  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로판다이올, 프...         20대      복합성
# 55  병풀추출물, 징크옥사이드 (CI 77947), 카프릴릴메티콘, 부틸옥틸살리실레이트,...         20대      복합성
# 56  정제수, 다이부틸아디페이트, 프로판다이올, 부틸옥틸살리실레이트, 에칠헥실트리아존, ...         20대  건성, 복합성
# 57  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 부틸옥틸살리실레이트, 프...         20대      복합성
# 58  정제수, 사이클로펜타실록세인, 징크옥사이드, 호모살레이트, 에칠헥실살리실레이트, 코...         20대      복합성
# 59  정제수, 징크옥사이드, 다이메티콘, 부틸옥틸살리실레이트, 폴리글리세릴-3폴리다이메틸...         20대  건성, 복합성
# 60  메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀\n비스에칠헥실옥시페놀메톡시페닐트리아진\n디...         20대      복합성
# 61  옥틸도데칸올, 징크옥사이드, 세틸에틸헥사노에이트, 벤조트라이아졸릴도데실p-크레솔, ...         20대      복합성
# 62  알로에베라잎추출물, 사이클로펜타실록세인, 호모살레이트, 에칠헥실살리실레이트, 티타늄...  20대,40대 이상  건성, 복합성
# 63  정제수,호모살레이트,에칠헥실메톡시신나메이트, 다이프로필렌글라이콜,에탄올,에칠헥실살리...         20대  건성, 복합성
# 64  정제수, 징크옥사이드, 프로필헵틸카프릴레이트, 부틸옥틸살리실레이트, 부틸렌글라이콜다...         20대      복합성

# %% [markdown]
# ## OCR

# %%
ocr_result=[]

with open("./ocr.txt", "r") as ocr_file:
    for line in ocr_file:
        line=line.strip()
        ocr_result.append(line)

print("OCR Result: ",ocr_result)
# Out:
# OCR Result:  ['미리스틱애씨드']

# %% [markdown]
# ## Recommendation Ranking after OCR

# %%
OCR_Ranked = Ranked
for i in range (len(ocr_result)):
    OCR_Ranked = OCR_Ranked[OCR_Ranked['성분'].str.contains(ocr_result[i])==False]
OCR_Ranked.reset_index(inplace=True)
OCR_Ranked.index=OCR_Ranked.index + 1
print("제외성분갯수:",len(Ranked)-len(OCR_Ranked))
# Out:
# 제외성분갯수: 7

# %%
OCR_Ranked = OCR_Ranked.drop(['index'], axis=1)
OCR_Ranked
# Out:
#                                                   상품명     가격  \
# 1                    닥터지 그린 마일드 업 선 플러스 기획(50ml+20ml)  29000
# 2      [베스트밀착차단] 셀퓨전씨 레이저 썬스크린 100 50ml 기획(쿨링패드 2매입2)  42000
# 3                                    조선미녀 맑은쌀선크림 50ml  18000
# 4                메이크프렘 유브이 디펜스 미 노 세범 선크림 40ml 1+1 기획  28000
# 5       [프롬젤라PICK] 톤핏선 비건 파데프리 핑베 테라조쿠션 SPF50+ PA++++  24000
# 6            라운드랩 자작나무 수분 톤업 선크림 50ml 기획(클렌저 20ml 증정)  25000
# 7       [베스트밀착톤업] 셀퓨전씨 토닝 썬스크린 100 50ml 기획(쿨링패드 2매입2)  39000
# 8                          [NEW] 라운드랩 자작나무 수분 선스틱 19g  24000
# 9                [쿨링젤] 아로마티카 수딩 알로에 베라 젤 (300ml500ml)  11000
# 10            라운드랩 자작나무 무기자차 선크림 50ml 기획(클렌저 20ml 증정)  25000
# 11          [단독기획] 아누아 어성초 실키 모이스처 선크림 기획 (50ml+10ml)  25000
# 12                       드림웍스 아임더 리얼 알로에 99%수딩젤 300ml   5800
# 13                [단독기획] 토리든 다이브인 워터리 모이스처 선크림 1+1 기획  25000
# 14                    한율 어린쑥 수분진정 선크림 50ml+20ml 증정 기획  27000
# 15                    아벤느 선 미네랄 크림 50ml SPF50+ PA++++  32000
# 16                                    조선미녀 산들쑥선스틱 18g  18000
# 17         아넷사 퍼펙트 UV 스킨케어 밀크 N 60ml 기획 (+썬패치 2회분 증정)  36000
# 18                      [대용량] AHC 내추럴 퍼펙션 프레쉬 선스틱 22g  19000
# 19            [단독기획] 비플레인 선뮤즈 모이스처 선크림 기획 (50ml+20ml)  26000
# 20       [톤업선크림 쿠션 VER] 달바 워터풀 톤업 선 쿠션 듀오 기획(15g+15g)  52500
# 21  [단독기획] 토리든 다이브인 무기자차 마일드 선크림 60ml 기획 (+20ml 추가...  25000
# 22                   닥터올가 프리미엄 선프로텍션 크림 60ml (톤업 선크림)  38000
# 23                                    조선미녀 인삼선세럼 50ml  21000
# 24        [퍼프 증정] 라타플랑 미나리 진정 선크림 기획세트 (50ml+20ml 증정)  25000
# 25              마녀공장 파데프리 선크림 모이스처 50ml SPF50+ PA++++  28000
# 26                       아넷사 퍼펙트 UV 선스크린 스킨케어 젤 N 90g  28000
# 27                  에끌라두 UV 오일프리 선크림 SPF50+PA ++++ 기획  28000
# 28                           컬러랩스 화이트태닝 100X 로션 300ml  32000
# 29                         성분에디터 그린토마토 포어 블러링 선크림 50g  24500
#
#                                                    성분       나이     피부타입
# 1   1. 그린마일드 업 선 플러스 50ml(본품+구성품)\n정제수, 징크옥사이드, 프로...      30대      복합성
# 2   정제수, 사이클로펜타실록산, 에칠헥실메톡시신나메이트, 부틸렌글라이콜, 에칠헥실살리실...  20대,30대      복합성
# 3   정제수, 쌀추출물, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실...      30대  건성, 복합성
# 4   정제수,징크옥사이드,사이클로헥사실록세인,부틸옥틸살리실레이트,프로판다이올,프로필헵틸카...      30대  지성, 복합성
# 5   정제수, 징크옥사이드, 부틸렌글라이콜다이카프릴레이트/다이카프레이트, 티타늄디옥사이드...      30대      복합성
# 6   [본품 : 자작나무 수분 톤업 선크림]\n정제수, 프로판다이올, 다이부틸아디페이트,...      30대  건성, 복합성
# 7   정제수, 사이클로펜타실록세인, 징크옥사이드, 호모살레이트, 에칠헥실살리실레이트, 코...      30대      복합성
# 8   정제수, 코코-카프릴레이트/카프레이트, 다이부틸아디페이트, 합성왁스, 부틸옥틸살리실...      30대  건성, 복합성
# 9   알로에베라잎추출물, 프로판다이올, 1,2-헥산다이올, 로즈마리잎수, 소듐카보머, 부...      30대      복합성
# 10  1. 자작나무 무기자차 선크림 50ml (본품)\n정제수, 징크옥사이드, 사이클로헥...      30대      복합성
# 11  정제수, 약모밀추출물(30%), 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존,...      30대  건성, 복합성
# 12  ■ 알로에베라잎추출물, 변성알코올, 정제수, 글리세린, 다이프로필렌글라이콜, 부틸렌...      30대      복합성
# 13  정제수, 프로판다이올, 다이부틸아디페이트, 비스-에칠헥실옥시페놀메톡시페닐트리아진, ...      30대  건성, 복합성
# 14  정제수, 다이부틸아디페이트, 부틸옥틸살리실레이트, 폴리메틸실세스퀴옥세인, 디에칠아미...      30대  건성, 복합성
# 15  티타늄디옥사이드\n아쿠아(아벤느 온천수)\n아이소데실네오펜타노에이트\n트라이에틸헥사...      30대  건성, 복합성
# 16  메틸메타크릴레이트크로스폴리머, 합성왁스, 다이부틸아디페이트, 코코-카프릴레이트/카프...  20대,30대      복합성
# 17  다이메티콘, 정제수, 징크옥사이드, 에탄올, 탤크, 옥토크릴렌, 아이소도데케인, 다...      30대      복합성
# 18  다이메티+B3:C67콘,비닐다이메티콘/메티콘실세스퀴옥세인크로스폴리머,폴리에틸렌,세틸...      30대  건성, 복합성
# 19  정제수, 다이부틸아디페이트, 프로판다이올, 폴리메틸실세스퀴옥세인, 다이아이소프로필세...      30대  건성, 복합성
# 20  정제수, 티타늄디옥사이드 (CI 77891), 부틸옥틸살리실레이트, 다이프로필렌글라...      30대  건성, 복합성
# 21  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로필헵틸카프릴레...      30대  건성, 복합성
# 22  알로에베라잎즙, 다이카프릴릴카보네이트, 징크옥사이드, 사이클로펜타실록세인, 티타늄디...      30대  건성, 복합성
# 23  정제수, 인삼추출물, 다이부틸아디페이트, 디에칠아미노하이드록시벤조일헥실벤조에이트, ...      30대  건성, 복합성
# 24  정제수, 미나리추출물, 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존, 테레프탈...      30대  건성, 복합성
# 25  정제수, 다이부틸아디페이트, 다이프로필렌글라이콜, 티타늄디옥사이드 (CI 77891...      30대  건성, 복합성
# 26  정제수, 에탄올, 에칠헥실메톡시신나메이트, 다이메티콘, 에칠헥실살리실레이트, 피이지...      30대  건성, 복합성
# 27  정제수, 에칠헥실메토시신나메이트, 다이프로필렌글라이콜, 티타늄디옥사이드, 다이부틸아...      30대  건성, 복합성
# 28  정제수, 글리세린, 부틸렌글라이콜, 카프릴릭/카프릭트라이글리세라이드, 나이아신아마이...  20대,30대  건성, 복합성
# 29  정제수, 다이부틸아디페이트, 에칠헥실트리아존, 디에칠아미노하이드록시벤조일헥실벤조에이...      30대      복합성

# %% [markdown]
# ## Others Ranking after OCR

# %%
OCR_others = others
for i in range (len(ocr_result)):
    OCR_others = OCR_others[OCR_others['성분'].str.contains(ocr_result[i])==False]
OCR_others.reset_index(inplace=True)
OCR_others.index=OCR_others.index + 1
print("제외성분갯수:",len(others)-len(OCR_others))
# Out:
# 제외성분갯수: 5

# %%
OCR_others = OCR_others.drop(['index'], axis=1)
OCR_others
# Out:
#                                                   상품명     가격  \
# 1            [1+1올영1위] 달바 워터풀 톤업 선크림 듀오 기획(50ml+50ml)  51000
# 2                 차앤박(CNP) 톤업프로텍션선SPF42 50ml 1+1 단독기획  28000
# 3                  [유리아PICK] 조선미녀 맑은쌀선크림 더블기획세트 50ml2  30000
# 4               라운드랩 자작나무 수분 선크림 50ml 기획(클렌저 20ml 증정)  25000
# 5   [1+1기획] 구달 맑은 어성초 진정 수분 선크림 50ml 1+1 기획 SPF50+...  18000
# 6               [베스트보송톤업] 닥터지 브라이트닝 업 선 플러스 40ml+40ml  40000
# 7   [1+1 기획] 구달 맑은 어성초 진정 무기자차 선크림 50ml 1+1 기획 SPF...  20000
# 8                  식물나라 산소수생기톤업선쿠션 리필기획 2color (2304)  24800
# 9   [수분진정] 넘버즈인 1번 청초 진정맑은 물막선크림 50ml+50ml 듀오기획 (S...  26000
# 10     [올영1위812만개 판매] 달바 워터풀 에센스 선크림 듀오 기획(50ml+50ml)  51000
# 11  식물나라 산소수가벼운수분선젤로션 SPF50+ PA++++ 더블 기획 (60ml+60ml)  25800
# 12             [베스트민감피부] 닥터지 그린 마일드 업 선 플러스 40ml+40ml  37000
# 13          [베스트보송톤업] 닥터지 브라이트닝 업 선 플러스 기획(50ml+20ml)  32000
# 14       넘버즈인 3번 도자기결 파데스킵 톤업베이지 50ml (SPF50+ PA++++)  26000
# 15             에스트라 더마UV365 장벽수분 무기자차 선크림 40ml 1+1 기획  31000
# 16           [베스트밀착차단] 셀퓨전씨 레이저 썬스크린 더블기획 (35ml+35ml)  29400
# 17                  김정문알로에 큐어 알로에 수딩젤 리뉴얼 150ml 1+1기획   9900
# 18  [더보이즈 큐PICK]듀이트리 어반쉐이드 더마 판테놀5 수분 장벽 선 1+1기획(4...  30000
# 19        [디렉터파이개발]에뛰드 순정 디렉터 수분 선크림 1+1기획(50ml+50ml)  25000
# 20         [증량기획] 에스쁘아 워터 스플래쉬 선크림 세라마이드 60ml+20ml 세트  22000
# 21     [디렉터파이개발]에뛰드 순정 디렉터 무기자차 선크림 1+1기획 (50ml+50ml)  25000
# 22                 토코보 바이오 워터리 선크림 50mL SPF50+ PA++++  24000
# 23             [무기자차논나노] 로벡틴 아쿠아 수딩 선크림 35ml 1+1 기획세트  42000
# 24                메이크프렘 유브이 디펜스 미 카밍톤업선크림 40ml 1+1 기획  28000
# 25           [박세리 공동개발  대용량 출시] AHC 마스터즈 에어리치 선스틱 22g  21000
# 26                 아떼 비건 릴리프 선 에센스 대용량 기획 (70ml+40ml)  42000
# 27    [올영1위812만개 판매] 달바 워터풀 마일드 선크림 듀오 기획 (50ml+50ml)  51000
# 28              [수분] 닥터지 레드 블레미쉬 수딩 업 선 기획(50ml+20ml)  29000
# 29  [듀오기획] 넘버즈인 3번 도자기결 파데스킵 톤업베이지 35ml+35ml (SPF5...  32000
# 30  [한정기획수분] 닥터지 레드 블레미쉬 수딩 업 선 50ml 1+1 한정 기획(볼펜 ...  29000
# 31       [파데프리] 넘버즈인 3번 도자기결 고이빚은 세라믹쿠션 SPF50+ PA++++  28000
# 32               메이크프렘 유브이 디펜스 미 워터리캡슐선크림 40ml 1+1 기획  28000
# 33          [단독기획] 비플레인 선뮤즈 톤업&코렉팅 선크림 기획 (50ml+20ml)  26000
# 34           브링그린 알로에99% 수딩젤 300ml단품더블기획(300ml+300ml)  13600
# 35    [더보이즈 큐PICK]듀이트리 어반쉐이드 안티폴루션 선 1+1기획(50ml+50ml)  30000
# 36  [디렉터파이 PICK] 싸이닉 엔조이 슈퍼 마일드 선 에센스 더블 기획 (50ml+...  15000
# 37                비욘드 엔젤아쿠아 수분 수딩젤 더블기획 (200ml+200ml)  15000
# 38  [유기자차 선크림]디어,클레어스 올 데이 에어리 선스크린 SPF50+ PA++++ 50g  19500
# 39                        식물나라 산소수워터프루프선크림(대용량) 100mL  19000
# 40                    셀퓨전씨 스틱 썬스크린 19g (SPF50+PA++++)  25000
# 41                          AHC 누드 톤업 크림 내추럴 글로우 40ml  29000
# 42                                 마녀공장 파데프리 선크림 50ml  28000
# 43                  [단독기획] 휘게 비건 선크림 더블 기획(35ml+35ml)  24300
# 44                      피지오겔 레드수딩 AI 센서티브 UV썬스크린 40ml  30000
# 45                  [NEW] 에스쁘아 워터 스플래쉬 선크림 세라마이드 60ml  22000
# 46   [더보이즈 큐PICK]듀이트리 어반쉐이드 커버 앤 핏 선 1+1기획(40ml+40ml)  24000
# 47                           닥터지 레드 블레미쉬 수딩 업 선스틱 21g  27000
# 48                     김정문알로에 큐어 아쿠아 마일드 그린 선 크림 40ml  25000
# 49               [한겹톤업] 아떼 비건 릴리프 톤업 선 비비 50ml 1+1 기획  34000
# 50                              AHC 세이프온 마일드 선 쿠션 25g  29000
# 51                       [화해1위]하멜 비건 아쿠아 글로우 선세럼 50ml  28000
# 52  에스트라 더마UV365 장벽수분 무기자차 선크림 40ml+10ml 기획 (+크림10...  31000
# 53           [베스트밀착톤업] 셀퓨전씨 토닝 썬스크린 1+1기획 (35ml+35ml)  27900
# 54                      차앤박(CNP) 마일드 카밍 선 50ml 1+1 기획  28000
# 55                  아벤느 비-프로텍트 썬크림 SPF50+ PA++++ 30ml  30000
# 56                         [민감피부] 닥터지 그린마일드 업 선스틱 20g  25000
# 57                             블랙몬스터 밸런싱 알로에 선크림 50ml  14000
# 58                             가히 링클 바운스 에센셜 선크림 50ml  24500
# 59               [선우PICK]메디힐 비타마이드 잡티 선크림 50ml 1+1 기획  25000
#
#                                                    성분          나이     피부타입
# 1   정제수, 다이부틸아디페이트, 프로판다이올, 티타늄디옥사이드, 카프릴릭/카프릭트라이글...         20대  건성, 복합성
# 2   정제수, 사이클로펜타실록산, 에칠헥실메톡시신나메이트, 에칠헥실살리실레이트, 징크옥사...         20대      복합성
# 3   정제수, 쌀추출물, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실...         20대  건성, 복합성
# 4   정제수, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실벤조에이트,...         20대  건성, 복합성
# 5   정제수, 다이부틸아디페이트, 프로판다이올, 폴리메틸실세스퀴옥세인, 다이아이소프로필세...         20대  건성, 복합성
# 6   정제수, 사이클로펜타실록세인, 에칠헥실메톡시신나메이트, 징크옥사이드 (CI 7794...         20대      복합성
# 7   정제수, 징크옥사이드, 부틸옥틸살리실레이트, 사이클로헥사실록세인, 카프릴릴메티콘, ...         20대      복합성
# 8   [1호 뽀얀 화이트]\n정제수,부틸옥틸살리실레이트,징크옥사이드,아이소데실네오펜타노에...         20대      복합성
# 9   스페인감초뿌리수(20.55%), 병풀추출물(15%), 약모밀추출물(14.25%), ...         20대  건성, 복합성
# 10  정제수, 에칠헥실메톡시신나메이트, 호모살레이트, 부틸렌글라이콜, 에칠헥실살리실레이트...         20대  건성, 복합성
# 11  정제수, 프로판다이올, 사이클로펜타실록세인, 에칠헥실살리실레이트, 호모살레이트, 다...         20대      복합성
# 12  정제수, 징크옥사이드, 프로판다이올, 부틸옥틸살리실레이트, 프로필헵틸카프릴레이트, ...         20대      복합성
# 13  1. 닥터지 브라이트닝 업 선 플러스 50ml(본품+구성품)\n정제수, 사이클로펜타...         20대      복합성
# 14  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 프로필헵틸카프릴레이트, ...         20대      복합성
# 15  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 부틸옥틸살리실레이트, 프...         20대      복합성
# 16  정제수, 사이클로펜타실록산, 에칠헥실메톡시신나메이트, 부틸렌글라이콜, 에칠헥실살리실...         20대      복합성
# 17  알로에베라잎즙(89.4%),디프로필렌글라이콜,1,2-헥산디올,에탄올,글리세린,트로메...         20대  건성, 복합성
# 18  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 판테놀, 프로판다...         20대  건성, 복합성
# 19  정제수, 다이부틸아디페이트, 프로판다이올, 부틸렌글라이콜, 에칠헥실트리아존, 테레프...         20대  건성, 복합성
# 20  정제수, 부틸렌글라이콜, C12-15알킬벤조에이트, 에칠헥실메톡시신나메이트, 티타늄...         20대  건성, 복합성
# 21  정제수, 아이소노닐아이소노나노에이트, 징크옥사이드, 프로판다이올, C12-15알킬벤...         20대      복합성
# 22  정제수, 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존, 테레프탈릴리덴디캠퍼설포...         20대  건성, 복합성
# 23  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로판다이올, 프...         20대      복합성
# 24  정제수,징크옥사이드,프로필헵틸카프릴레이트,프로판다이올,티타늄디옥사이드,다이실록세인,...      40대 이상      복합성
# 25  메틸메타크릴레이트크로스폴리머, 폴리에틸렌, 카프릴릴메티콘, 코코-카프릴레이트/카프레...         20대  지성, 복합성
# 26  정제수,프로판다이올,사이클로펜타실록세인,에칠헥실살리실레이트,호모살레이트,다이부틸아디...         20대  건성, 복합성
# 27  정제수, C12-15알킬벤조에이트, 티타늄디옥사이드, 벤조트라이아졸릴도데실p-크레솔...         20대  건성, 복합성
# 28  1. 닥터지 레드 블레미쉬 수딩 업 선 50ml (본품)\n\n정제수, 다이부틸아디...         20대  건성, 복합성
# 29  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 프로필헵틸카프릴레이트, ...         20대      복합성
# 30  정제수, 다이부틸아디페이트, 프로판다이올, 에칠헥실트리아존, 테레프탈릴리덴디캠퍼설포...         20대  건성, 복합성
# 31  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 프로필헵틸카프릴레이트, ...         20대  건성, 복합성
# 32  정제수,다이부틸아디페이트,폴리메틸실세스퀴옥세인,프로판다이올,디에칠아미노하이드록시벤조...         20대  건성, 복합성
# 33  정제수, 에칠헥실트리아존, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤...         20대      복합성
# 34  ■ 알로에베라잎즙(99%), 글리세린, 알지닌,카보머, 1,2-헥산다이올, 정제수,...         20대      복합성
# 35  정제수, 징크옥사이드, 프로필헵틸카프릴레이트, 프로판다이올, 티타늄디옥사이드, 부틸...         20대      복합성
# 36  정제수, 다이부틸아디페이트, 프로판다이올, 디에칠아미노하이드록시벤조일헥실벤조에이트,...         20대  건성, 복합성
# 37  정제수, 글리세린, 1,2-헥산다이올, 마데카소사이드, 알로에베라잎추출물, 포도덩굴...         20대  건성, 복합성
# 38  정제수, 다이부틸아디페이트, 부틸옥틸살리실레\n이트, 디에칠아미노하이드록시벤조일헥실...         20대  건성, 복합성
# 39  정제수, 사이클로펜타실록세인, 징크옥사이드, 호모살레이트, 에칠헥실살리실레이트, 폴...         20대      복합성
# 40  정제수, 폴리에틸렌, 다이메티콘, 호모살레이트, 메틸메타크릴레이트크로스폴리머, 에칠...         20대      복합성
# 41  크림: 정제수,카프릴릭/카프릭트라이글리세라이드,프로필렌글라이콜다이벤조에이트,다이프로...      40대 이상       건성
# 42  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로판다이올, 프...         20대      복합성
# 43  정제수, 에탄올, 디에칠아미노하이드록시벤조일헥실벤조에이트, 비스-에칠헥실옥시페놀메톡...         20대  건성, 복합성
# 44  정제수, 에칠헥실메톡시신나메이트, 에칠헥실살리실레이트, C12-15알킬벤조에이트, ...      40대 이상  건성, 복합성
# 45  정제수, 부틸렌글라이콜, C12-15알킬벤조에이트, 에칠헥실메톡시신나메이트, 티타늄...         20대  건성, 복합성
# 46  정제수, 티타늄디옥사이드, 페닐트라이메티콘, 부틸렌글라이콜, 부틸옥틸살리실레이트, ...         20대      복합성
# 47  정제수, 코코-카프릴레이트/카프레이트, 다이부틸아디페이트, 합성왁스, 부틸옥틸살리실...         20대  건성, 복합성
# 48  알로에베라잎즙, 징크옥사이드, 사이클로헥사실록세인, 메틸트라이메티콘, 부틸 옥틸살리...         20대  건성, 복합성
# 49  정제수, 징크옥사이드, 사이클로헥사실록세인, 부틸옥틸살리실레이트, 프로판다이올, 프...         20대      복합성
# 50  병풀추출물, 징크옥사이드 (CI 77947), 카프릴릴메티콘, 부틸옥틸살리실레이트,...         20대      복합성
# 51  정제수, 다이부틸아디페이트, 프로판다이올, 부틸옥틸살리실레이트, 에칠헥실트리아존, ...         20대  건성, 복합성
# 52  정제수, 징크옥사이드, 사이클로헥사실록세인, 프로판다이올, 부틸옥틸살리실레이트, 프...         20대      복합성
# 53  정제수, 사이클로펜타실록세인, 징크옥사이드, 호모살레이트, 에칠헥실살리실레이트, 코...         20대      복합성
# 54  정제수, 징크옥사이드, 다이메티콘, 부틸옥틸살리실레이트, 폴리글리세릴-3폴리다이메틸...         20대  건성, 복합성
# 55  메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀\n비스에칠헥실옥시페놀메톡시페닐트리아진\n디...         20대      복합성
# 56  옥틸도데칸올, 징크옥사이드, 세틸에틸헥사노에이트, 벤조트라이아졸릴도데실p-크레솔, ...         20대      복합성
# 57  알로에베라잎추출물, 사이클로펜타실록세인, 호모살레이트, 에칠헥실살리실레이트, 티타늄...  20대,40대 이상  건성, 복합성
# 58  정제수,호모살레이트,에칠헥실메톡시신나메이트, 다이프로필렌글라이콜,에탄올,에칠헥실살리...         20대  건성, 복합성
# 59  정제수, 징크옥사이드, 프로필헵틸카프릴레이트, 부틸옥틸살리실레이트, 부틸렌글라이콜다...         20대      복합성
